# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
import os
# Update this path to match your folder name exactly
PROJECT_PATH = '/content/drive/MyDrive/Colab Notebooks/deep_learning_project'

if os.path.exists(PROJECT_PATH):
    print(f"✅ Success! Found project at: {PROJECT_PATH}")
    os.chdir(PROJECT_PATH)
else:
    print(f"❌ Error: The path '{PROJECT_PATH}' does not exist.")
# Out:
# Mounted at /content/drive
# ✅ Success! Found project at: /content/drive/MyDrive/Colab Notebooks/deep_learning_project

# %%
# --- CELL 2: Imports & Configuration ---
import torch
import time
import pandas as pd
import matplotlib.pyplot as plt
from src.data_utils import get_split_cifar10
from src.models import get_resnet18
from src.trainer import train_baseline, train_constrained, evaluate
from src.decompositions import SVDProjector, QRProjector, RSVDProjector, MagnitudePruningProjector, AdaptiveSVDProjector

# CONFIGURATION
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
BATCH_SIZE = 64
EPOCHS_A = 20
task_b_epochs_list = [5, 10, 15]

results = []
print("Configuration Complete. Results list initialized.")
# Out:
# Configuration Complete. Results list initialized.

# %%
# --- CELL 3: Infrastructure & Baseline (Task A) ---
print("--- Phase 1: Data Setup ---")
train_A, test_A, train_B, test_B = get_split_cifar10(BATCH_SIZE)

print("--- Phase 2: Training Expert Model (Task A) ---")
model_expert = get_resnet18(num_classes=10).to(DEVICE)
model_expert = train_baseline(model_expert, train_A, EPOCHS_A, DEVICE)

# Checkpoint the expert
torch.save(model_expert.state_dict(), "checkpoints/task_a_expert.pth")
acc_A_initial = evaluate(model_expert, test_A, DEVICE, task_classes=[0, 1, 2, 3, 4])
print(f"Task A Expert Accuracy: {acc_A_initial:.2f}%")
# Out:
# --- Phase 1: Data Setup ---
# --- Phase 2: Training Expert Model (Task A) ---
# Starting Baseline Training (Task A)...
# Epoch 1/20 completed.
# Epoch 2/20 completed.
# Epoch 3/20 completed.
# Epoch 4/20 completed.
# Epoch 5/20 completed.
# Epoch 6/20 completed.
# Epoch 7/20 completed.
# Epoch 8/20 completed.
# Epoch 9/20 completed.
# Epoch 10/20 completed.
# Epoch 11/20 completed.
# Epoch 12/20 completed.
# Epoch 13/20 completed.
# Epoch 14/20 completed.
# Epoch 15/20 completed.
# Epoch 16/20 completed.
# Epoch 17/20 completed.
# Epoch 18/20 completed.
# Epoch 19/20 completed.
# Epoch 20/20 completed.
# Task A Expert Accuracy: 81.20%

# %%
# --- CELL 4: Experiment 1 - Naive Baseline ---
print("\n--- Experiment: Naive ---")


for epochs_b in task_b_epochs_list:
    print(f"\n>>> Training for {epochs_b} epochs...")

    # 1. Reload Clean Weights
    model_current = get_resnet18(num_classes=10).to(DEVICE)
    model_current.load_state_dict(torch.load("checkpoints/task_a_expert.pth"))

    # 2. Zero-Shot Eval (For Uniformity)
    acc_A_zero = evaluate(model_current, test_A, DEVICE, task_classes=[0, 1, 2, 3, 4])
    compression_damage = acc_A_initial - acc_A_zero

    # 3. Capture Start State
    # Save a snapshot of the weights after decomposition/pruning but before training
    w_start = {name: param.detach().cpu().clone() for name, param in model_current.named_parameters()}

    # 4. Train without constraints
    model_current = train_baseline(model_current, train_B, epochs_b, DEVICE)

    # 5. Drift Calc
    drift_sq = 0.0
    for name, param in model_current.named_parameters():
        if name in w_start:
            diff = param.detach().cpu() - w_start[name]
            drift_sq += torch.sum(diff ** 2).item()
    weight_drift = drift_sq ** 0.5

    # 6. Metrics
    acc_A_final = evaluate(model_current, test_A, DEVICE, task_classes=[0, 1, 2, 3, 4])
    acc_B_final = evaluate(model_current, test_B, DEVICE, task_classes=[5, 6, 7, 8, 9])
    forgetting = acc_A_initial - acc_A_final

    results.append({
        "Method": "Naive",
        "Task A Acc (Retention)": acc_A_final,
        "Task B Acc (Plasticity)": acc_B_final,
        "Forgetting": forgetting,
        "Zero-Shot A": acc_A_zero,
        "Compression Damage": compression_damage,
        "Forgetting (Training)": acc_A_zero - acc_A_final,
        "Prep Time (s)": 0,
        "Peak VRAM (MB)": 0,
        "Weight Drift": weight_drift,
        "Epochs": epochs_b
    })
    print(f"Naive Result (Epochs={epochs_b}): Initial A={acc_A_initial:.2f}%, Final B={acc_B_final:.2f}%, Final A={acc_A_final:.2f}%, Forgetting={forgetting:.2f}%, Drift={weight_drift:.4f}")
# Out:
# --- Experiment: Naive ---
#
# >>> Training for 5 epochs...
# Starting Baseline Training (Task A)...
# Epoch 1/5 completed.
# Epoch 2/5 completed.
# Epoch 3/5 completed.
# Epoch 4/5 completed.
# Epoch 5/5 completed.
# Naive Result (Epochs=5): Initial A=81.20%, Final B=87.78%, Final A=35.64%, Forgetting=45.56%, Drift=72.9948
#
# >>> Training for 10 epochs...
# Starting Baseline Training (Task A)...
# Epoch 1/10 completed.
# Epoch 2/10 completed.
# Epoch 3/10 completed.
# Epoch 4/10 completed.
# Epoch 5/10 completed.
# Epoch 6/10 completed.
# Epoch 7/10 completed.
# Epoch 8/10 completed.
# Epoch 9/10 completed.
# Epoch 10/10 completed.
# Naive Result (Epochs=10): Initial A=81.20%, Final B=88.50%, Final A=44.00%, Forgetting=37.20%, Drift=98.6247
#
# >>> Training for 15 epochs...
# Starting Baseline Training (Task A)...
# Epoch 1/15 completed.
# Epoch 2/15 completed.
# Epoch 3/15 completed.
# Epoch 4/15 completed.
# Epoch 5/15 completed.
# Epoch 6/15 completed.
# Epoch 7/15 completed.
# ...

# %%
# --- CELL 5: Experiment 2 - Standard SVD ---
print("\n--- Experiment: SVD ---")


# --- Phase 1: Heavy Computation (Run Once) ---
model_for_projection = get_resnet18(num_classes=10).to(DEVICE)
model_for_projection.load_state_dict(torch.load("checkpoints/task_a_expert.pth"))

# Subspace Extraction
projector = SVDProjector()

# --- VRAM Measurement Start ---
if torch.cuda.is_available():
    torch.cuda.reset_peak_memory_stats()
    torch.cuda.empty_cache()
# ------------------------------

start_time = time.time()
projector.compute_subspaces(model_for_projection)

# --- VRAM Measurement End ---
peak_vram = 0
if torch.cuda.is_available():
    peak_vram = torch.cuda.max_memory_allocated() / (1024 ** 2)
# ----------------------------

prep_time = time.time() - start_time
print(f"Subspace computed in {prep_time:.2f}s")

# --- Phase 2: The Loop ---
for epochs_b in task_b_epochs_list:
    print(f"\n>>> Training for {epochs_b} epochs...")

    # 1. Reload Clean Weights
    model_current = get_resnet18(num_classes=10).to(DEVICE)
    model_current.load_state_dict(torch.load("checkpoints/task_a_expert.pth"))

    # 2. Zero-Shot Eval
    acc_A_zero = evaluate(model_current, test_A, DEVICE, task_classes=[0, 1, 2, 3, 4])
    compression_damage = acc_A_initial - acc_A_zero
    print(f"Zero-Shot A Accuracy: {acc_A_zero:.2f}% (Drop: {compression_damage:.2f}%)")

    # 3. Capture Start State
    w_start = {name: param.detach().cpu().clone() for name, param in model_current.named_parameters()}

    # 4. Constrained Training
    model_current = train_constrained(model_current, train_B, epochs_b, DEVICE, projector)

    # 5. Drift Calc
    drift_sq = 0.0
    for name, param in model_current.named_parameters():
        if name in w_start:
            diff = param.detach().cpu() - w_start[name]
            drift_sq += torch.sum(diff ** 2).item()
    weight_drift = drift_sq ** 0.5

    # 6. Metrics
    acc_A_final = evaluate(model_current, test_A, DEVICE, task_classes=[0, 1, 2, 3, 4])
    acc_B_final = evaluate(model_current, test_B, DEVICE, task_classes=[5, 6, 7, 8, 9])
    forgetting = acc_A_initial - acc_A_final

    results.append({
        "Method": "SVD",
        "Task A Acc (Retention)": acc_A_final,
        "Task B Acc (Plasticity)": acc_B_final,
        "Forgetting": forgetting,
        "Zero-Shot A": acc_A_zero,
        "Compression Damage": compression_damage,
        "Forgetting (Training)": acc_A_zero - acc_A_final,
        "Prep Time (s)": prep_time,
        "Peak VRAM (MB)": peak_vram,
        "Weight Drift": weight_drift,
        "Epochs": epochs_b
    })
    print(f"SVD Result (Epochs={epochs_b}): Initial A={acc_A_initial:.2f}%, Final B={acc_B_final:.2f}%, Final A={acc_A_final:.2f}%, Forgetting={forgetting:.2f}%, Drift={weight_drift:.4f}, Prep Time={prep_time:.2f}s, Peak VRAM={peak_vram:.2f}MB")
# Out:
# --- Experiment: SVD ---
# Subspace computed in 0.69s
#
# >>> Training for 5 epochs...
# Zero-Shot A Accuracy: 81.20% (Drop: 0.00%)
# Starting Constrained Training (Method: SVDProjector)...
# Epoch 1/5 completed.
# Epoch 2/5 completed.
# Epoch 3/5 completed.
# Epoch 4/5 completed.
# Epoch 5/5 completed.
# SVD Result (Epochs=5): Initial A=81.20%, Final B=87.46%, Final A=39.64%, Forgetting=41.56%, Drift=121.4029, Prep Time=0.69s, Peak VRAM=358.35MB
#
# >>> Training for 10 epochs...
# Zero-Shot A Accuracy: 81.20% (Drop: 0.00%)
# Starting Constrained Training (Method: SVDProjector)...
# Epoch 1/10 completed.
# Epoch 2/10 completed.
# Epoch 3/10 completed.
# Epoch 4/10 completed.
# Epoch 5/10 completed.
# Epoch 6/10 completed.
# Epoch 7/10 completed.
# Epoch 8/10 completed.
# Epoch 9/10 completed.
# Epoch 10/10 completed.
# SVD Result (Epochs=10): Initial A=81.20%, Final B=88.56%, Final A=44.54%, Forgetting=36.66%, Drift=155.0379, Prep Time=0.69s, Peak VRAM=358.35MB
#
# ...

# %%
# --- CELL 6: Experiment 3 - Adaptive SVD ---
print("\n--- Experiment: Adaptive SVD ---")


# --- Phase 1: Heavy Computation (Run Once) ---
model_for_projection = get_resnet18(num_classes=10).to(DEVICE)
model_for_projection.load_state_dict(torch.load("checkpoints/task_a_expert.pth"))

# Subspace Extraction
# We set mrr=0.4 (40% min retention) and trr=0.95 (95% max retention)
projector = AdaptiveSVDProjector(mrr=0.4, trr=0.95)

# --- VRAM Measurement Start ---
if torch.cuda.is_available():
    torch.cuda.reset_peak_memory_stats()
    torch.cuda.empty_cache()
# ------------------------------

start_time = time.time()
# Using test_A (Task A) loader to evaluate importance for RETAINING Task A
projector.compute_subspaces(model_for_projection, test_A, DEVICE)

# --- VRAM Measurement End ---
peak_vram = 0
if torch.cuda.is_available():
    peak_vram = torch.cuda.max_memory_allocated() / (1024 ** 2)
# ----------------------------

prep_time = time.time() - start_time
print(f"Subspace computed in {prep_time:.2f}s")

# --- Phase 2: The Loop ---
for epochs_b in task_b_epochs_list:
    print(f"\n>>> Training for {epochs_b} epochs...")

    # 1. Reload Clean Weights
    model_current = get_resnet18(num_classes=10).to(DEVICE)
    model_current.load_state_dict(torch.load("checkpoints/task_a_expert.pth"))

    # 2. Zero-Shot Eval
    acc_A_zero = evaluate(model_current, test_A, DEVICE, task_classes=[0, 1, 2, 3, 4])
    compression_damage = acc_A_initial - acc_A_zero
    print(f"Zero-Shot A Accuracy: {acc_A_zero:.2f}% (Drop: {compression_damage:.2f}%)")

    # 3. Capture Start State
    w_start = {name: param.detach().cpu().clone() for name, param in model_current.named_parameters()}

    # 4. Constrained Training
    model_current = train_constrained(model_current, train_B, epochs_b, DEVICE, projector)

    # 5. Drift Calc
    drift_sq = 0.0
    for name, param in model_current.named_parameters():
        if name in w_start:
            diff = param.detach().cpu() - w_start[name]
            drift_sq += torch.sum(diff ** 2).item()
    weight_drift = drift_sq ** 0.5

    # 6. Metrics
    acc_A_final = evaluate(model_current, test_A, DEVICE, task_classes=[0, 1, 2, 3, 4])
    acc_B_final = evaluate(model_current, test_B, DEVICE, task_classes=[5, 6, 7, 8, 9])
    forgetting = acc_A_initial - acc_A_final

    results.append({
        "Method": "Adaptive SVD",
        "Task A Acc (Retention)": acc_A_final,
        "Task B Acc (Plasticity)": acc_B_final,
        "Forgetting": forgetting,
        "Zero-Shot A": acc_A_zero,
        "Compression Damage": compression_damage,
        "Forgetting (Training)": acc_A_zero - acc_A_final,
        "Prep Time (s)": prep_time,
        "Peak VRAM (MB)": peak_vram,
        "Weight Drift": weight_drift,
        "Epochs": epochs_b
    })
    print(f"Adaptive SVD Result (Epochs={epochs_b}): Initial A={acc_A_initial:.2f}%, Final B={acc_B_final:.2f}%, Final A={acc_A_final:.2f}%, Forgetting={forgetting:.2f}%, Drift={weight_drift:.4f}, Prep Time={prep_time:.2f}s, Peak VRAM={peak_vram:.2f}MB")
# Out:
# --- Experiment: Adaptive SVD ---
# Adaptive SVD: Avg Importance = 0.4044 (over 13 matching layers)
# Subspace computed in 0.45s
#
# >>> Training for 5 epochs...
# Zero-Shot A Accuracy: 81.20% (Drop: 0.00%)
# Starting Constrained Training (Method: AdaptiveSVDProjector)...
# Epoch 1/5 completed.
# Epoch 2/5 completed.
# Epoch 3/5 completed.
# Epoch 4/5 completed.
# Epoch 5/5 completed.
# Adaptive SVD Result (Epochs=5): Initial A=81.20%, Final B=87.80%, Final A=46.46%, Forgetting=34.74%, Drift=126.4205, Prep Time=0.45s, Peak VRAM=380.47MB
#
# >>> Training for 10 epochs...
# Zero-Shot A Accuracy: 81.20% (Drop: 0.00%)
# Starting Constrained Training (Method: AdaptiveSVDProjector)...
# Epoch 1/10 completed.
# Epoch 2/10 completed.
# Epoch 3/10 completed.
# Epoch 4/10 completed.
# Epoch 5/10 completed.
# Epoch 6/10 completed.
# Epoch 7/10 completed.
# Epoch 8/10 completed.
# Epoch 9/10 completed.
# Epoch 10/10 completed.
# ...

# %%
# --- CELL 7: Experiment 4 - Pivoted QR Decomposition ---
print("\n--- Experiment: Pivoted QR Decomposition ---")


# --- Phase 1: Heavy Computation (Run Once) ---
model_for_projection = get_resnet18(num_classes=10).to(DEVICE)
model_for_projection.load_state_dict(torch.load("checkpoints/task_a_expert.pth"))

# Subspace Extraction
# rank_fraction=0.5 ensures fair comparison with Standard SVD (50%)
qr_projector = QRProjector(rank_fraction=0.5)

# --- VRAM Measurement Start ---
if torch.cuda.is_available():
    torch.cuda.reset_peak_memory_stats()
    torch.cuda.empty_cache()
# ------------------------------

start_time = time.time()
qr_projector.compute_subspaces(model_for_projection, device=DEVICE)

# --- VRAM Measurement End ---
peak_vram = 0
if torch.cuda.is_available():
    peak_vram = torch.cuda.max_memory_allocated() / (1024 ** 2)
# ----------------------------

prep_time = time.time() - start_time
print(f"QR Subspace computed in {prep_time:.2f}s")

# --- Phase 2: The Loop ---
for epochs_b in task_b_epochs_list:
    print(f"\n>>> Training for {epochs_b} epochs...")

    # 1. Reload Clean Weights
    model_current = get_resnet18(num_classes=10).to(DEVICE)
    model_current.load_state_dict(torch.load("checkpoints/task_a_expert.pth"))

    # 2. Zero-Shot Eval
    acc_A_zero = evaluate(model_current, test_A, DEVICE, task_classes=[0, 1, 2, 3, 4])
    compression_damage = acc_A_initial - acc_A_zero
    print(f"Zero-Shot A Accuracy: {acc_A_zero:.2f}% (Drop: {compression_damage:.2f}%)")

    # 3. Capture Start State
    w_start = {name: param.detach().cpu().clone() for name, param in model_current.named_parameters()}

    # 4. Constrained Training
    model_current = train_constrained(model_current, train_B, epochs_b, DEVICE, qr_projector)

    # 5. Drift Calc
    drift_sq = 0.0
    for name, param in model_current.named_parameters():
        if name in w_start:
            diff = param.detach().cpu() - w_start[name]
            drift_sq += torch.sum(diff ** 2).item()
    weight_drift = drift_sq ** 0.5

    # 6. Metrics
    acc_A_final = evaluate(model_current, test_A, DEVICE, task_classes=[0, 1, 2, 3, 4])
    acc_B_final = evaluate(model_current, test_B, DEVICE, task_classes=[5, 6, 7, 8, 9])
    forgetting = acc_A_initial - acc_A_final

    results.append({
        "Method": "Pivoted QR",
        "Task A Acc (Retention)": acc_A_final,
        "Task B Acc (Plasticity)": acc_B_final,
        "Forgetting": forgetting,
        "Zero-Shot A": acc_A_zero,
        "Compression Damage": compression_damage,
        "Forgetting (Training)": acc_A_zero - acc_A_final,
        "Prep Time (s)": prep_time,
        "Peak VRAM (MB)": peak_vram,
        "Weight Drift": weight_drift,
        "Epochs": epochs_b
    })
    print(f"Pivoted QR Result (Epochs={epochs_b}): Initial A={acc_A_initial:.2f}%, Final B={acc_B_final:.2f}%, Final A={acc_A_final:.2f}%, Forgetting={forgetting:.2f}%, Drift={weight_drift:.4f}, Prep Time={prep_time:.2f}s, Peak VRAM={peak_vram:.2f}MB")
# Out:
# --- Experiment: Pivoted QR Decomposition ---
# Computing QR subspaces (Pivoted) using Scipy...
# QR Subspace computed in 2.07s
#
# >>> Training for 5 epochs...
# Zero-Shot A Accuracy: 81.20% (Drop: 0.00%)
# Starting Constrained Training (Method: QRProjector)...
# Epoch 1/5 completed.
# Epoch 2/5 completed.
# Epoch 3/5 completed.
# Epoch 4/5 completed.
# Epoch 5/5 completed.
# Pivoted QR Result (Epochs=5): Initial A=81.20%, Final B=87.46%, Final A=51.84%, Forgetting=29.36%, Drift=87.4355, Prep Time=2.07s, Peak VRAM=328.92MB
#
# >>> Training for 10 epochs...
# Zero-Shot A Accuracy: 81.20% (Drop: 0.00%)
# Starting Constrained Training (Method: QRProjector)...
# Epoch 1/10 completed.
# Epoch 2/10 completed.
# Epoch 3/10 completed.
# Epoch 4/10 completed.
# Epoch 5/10 completed.
# Epoch 6/10 completed.
# Epoch 7/10 completed.
# Epoch 8/10 completed.
# Epoch 9/10 completed.
# Epoch 10/10 completed.
# ...

# %%
# --- CELL 8: Experiment 5 - Randomized SVD ---
print("\n--- Experiment: RSVD ---")


# --- Phase 1: Heavy Computation (Run Once) ---
model_for_projection = get_resnet18(num_classes=10).to(DEVICE)
model_for_projection.load_state_dict(torch.load("checkpoints/task_a_expert.pth"))

# Subspace Extraction
projector = RSVDProjector(rank_fraction=0.5, p=10, q=2)

# --- VRAM Measurement Start ---
if torch.cuda.is_available():
    torch.cuda.reset_peak_memory_stats()
    torch.cuda.empty_cache()
# ------------------------------

start_time = time.time()
projector.compute_subspaces(model_for_projection)

# --- VRAM Measurement End ---
peak_vram = 0
if torch.cuda.is_available():
    peak_vram = torch.cuda.max_memory_allocated() / (1024 ** 2)
# ----------------------------

prep_time = time.time() - start_time
print(f"Subspace computed in {prep_time:.2f}s")

# --- Phase 2: The Loop ---
for epochs_b in task_b_epochs_list:
    print(f"\n>>> Training for {epochs_b} epochs...")

    # 1. Reload Clean Weights
    model_current = get_resnet18(num_classes=10).to(DEVICE)
    model_current.load_state_dict(torch.load("checkpoints/task_a_expert.pth"))

    # 2. Zero-Shot Eval
    acc_A_zero = evaluate(model_current, test_A, DEVICE, task_classes=[0, 1, 2, 3, 4])
    compression_damage = acc_A_initial - acc_A_zero
    print(f"Zero-Shot A Accuracy: {acc_A_zero:.2f}% (Drop: {compression_damage:.2f}%)")

    # 3. Capture Start State
    w_start = {name: param.detach().cpu().clone() for name, param in model_current.named_parameters()}

    # 4. Constrained Training
    model_current = train_constrained(model_current, train_B, epochs_b, DEVICE, projector)

    # 5. Drift Calc
    drift_sq = 0.0
    for name, param in model_current.named_parameters():
        if name in w_start:
            diff = param.detach().cpu() - w_start[name]
            drift_sq += torch.sum(diff ** 2).item()
    weight_drift = drift_sq ** 0.5

    # 6. Metrics
    acc_A_final = evaluate(model_current, test_A, DEVICE, task_classes=[0, 1, 2, 3, 4])
    acc_B_final = evaluate(model_current, test_B, DEVICE, task_classes=[5, 6, 7, 8, 9])
    forgetting = acc_A_initial - acc_A_final

    results.append({
        "Method": "RSVD",
        "Task A Acc (Retention)": acc_A_final,
        "Task B Acc (Plasticity)": acc_B_final,
        "Forgetting": forgetting,
        "Zero-Shot A": acc_A_zero,
        "Compression Damage": compression_damage,
        "Forgetting (Training)": acc_A_zero - acc_A_final,
        "Prep Time (s)": prep_time,
        "Peak VRAM (MB)": peak_vram,
        "Weight Drift": weight_drift,
        "Epochs": epochs_b
    })
    print(f"RSVD Result (Epochs={epochs_b}): Initial A={acc_A_initial:.2f}%, Final B={acc_B_final:.2f}%, Final A={acc_A_final:.2f}%, Forgetting={forgetting:.2f}%, Drift={weight_drift:.4f}, Prep Time={prep_time:.2f}s, Peak VRAM={peak_vram:.2f}MB")
# Out:
# --- Experiment: RSVD ---
# Subspace computed in 0.38s
#
# >>> Training for 5 epochs...
# Zero-Shot A Accuracy: 81.20% (Drop: 0.00%)
# Starting Constrained Training (Method: RSVDProjector)...
# Epoch 1/5 completed.
# Epoch 2/5 completed.
# Epoch 3/5 completed.
# Epoch 4/5 completed.
# Epoch 5/5 completed.
# RSVD Result (Epochs=5): Initial A=81.20%, Final B=88.64%, Final A=54.30%, Forgetting=26.90%, Drift=112.7191, Prep Time=0.38s, Peak VRAM=342.10MB
#
# >>> Training for 10 epochs...
# Zero-Shot A Accuracy: 81.20% (Drop: 0.00%)
# Starting Constrained Training (Method: RSVDProjector)...
# Epoch 1/10 completed.
# Epoch 2/10 completed.
# Epoch 3/10 completed.
# Epoch 4/10 completed.
# Epoch 5/10 completed.
# Epoch 6/10 completed.
# Epoch 7/10 completed.
# Epoch 8/10 completed.
# Epoch 9/10 completed.
# Epoch 10/10 completed.
# RSVD Result (Epochs=10): Initial A=81.20%, Final B=88.16%, Final A=55.96%, Forgetting=25.24%, Drift=147.2970, Prep Time=0.38s, Peak VRAM=342.10MB
#
# ...

# %%
# --- CELL 9: Experiment 6 - Global Magnitude Pruning ---
print("\n--- Experiment: Global Magnitude Pruning ---")

sparsity_targets = [0.2, 0.4, 0.6]

for sp in sparsity_targets:
    print(f"\n>>> Testing Sparsity Target: {sp*100:.0f}%")

    for epochs_b in task_b_epochs_list:
        print(f"   > Epochs: {epochs_b}")

        # 1. Reload Clean Weights
        model_current = get_resnet18(num_classes=10).to(DEVICE)
        model_current.load_state_dict(torch.load("checkpoints/task_a_expert.pth"))

        # 2. Pruning (Subspace Extraction) - Run INSIDE loop
        projector = MagnitudePruningProjector(sparsity_target=sp)

        # --- VRAM Measurement Start ---
        if torch.cuda.is_available():
            torch.cuda.reset_peak_memory_stats()
            torch.cuda.empty_cache()
        # ------------------------------

        start_time = time.time()
        projector.compute_subspaces(model_current)

        # --- VRAM Measurement End ---
        peak_vram = 0
        if torch.cuda.is_available():
            peak_vram = torch.cuda.max_memory_allocated() / (1024 ** 2)
        # ----------------------------

        prep_time = time.time() - start_time

        # 3. Zero-Shot Evaluation
        acc_A_zero = evaluate(model_current, test_A, DEVICE, task_classes=[0, 1, 2, 3, 4])
        compression_damage = acc_A_initial - acc_A_zero
        print(f"Zero-Shot: {acc_A_zero:.2f}% (Compression Damage: {compression_damage:.2f}%)")

        # 4. Capture Start State
        w_start = {name: param.detach().cpu().clone() for name, param in model_current.named_parameters()}

        # 5. Constrained Training
        model_current = train_constrained(model_current, train_B, epochs_b, DEVICE, projector)

        # 6. Drift Calc
        drift_sq = 0.0
        for name, param in model_current.named_parameters():
            if name in w_start:
                diff = param.detach().cpu() - w_start[name]
                drift_sq += torch.sum(diff ** 2).item()
        weight_drift = drift_sq ** 0.5

        # 7. Metrics
        acc_A_final = evaluate(model_current, test_A, DEVICE, task_classes=[0, 1, 2, 3, 4])
        acc_B_final = evaluate(model_current, test_B, DEVICE, task_classes=[5, 6, 7, 8, 9])
        forgetting = acc_A_initial - acc_A_final

        results.append({
            "Method": f"Pruning ({sp*100:.0f}%)",
            "Sparsity": sp,
            "Task A Acc (Retention)": acc_A_final,
            "Task B Acc (Plasticity)": acc_B_final,
            "Forgetting": forgetting,
            "Zero-Shot A": acc_A_zero,
            "Compression Damage": compression_damage,
            "Forgetting (Training)": acc_A_zero - acc_A_final,
            "Prep Time (s)": prep_time,
            "Peak VRAM (MB)": peak_vram,
            "Weight Drift": weight_drift,
            "Epochs": epochs_b
        })
        print(f"Pruning ({sp*100:.0f}%) Result (Epochs={epochs_b}): Initial A={acc_A_initial:.2f}%, Final B={acc_B_final:.2f}%, Final A={acc_A_final:.2f}%, Forgetting={forgetting:.2f}%, Drift={weight_drift:.4f}, Prep Time={prep_time:.2f}s, Peak VRAM={peak_vram:.2f}MB")
# Out:
# --- Experiment: Global Magnitude Pruning ---
#
# >>> Testing Sparsity Target: 20%
#    > Epochs: 5
# Pruning 21 layers with Global Sparsity 20.0%...
# Global Sparsity Achieved: 20.00%
# Zero-Shot: 81.22% (Compression Damage: -0.02%)
# Starting Constrained Training (Method: MagnitudePruningProjector)...
# Epoch 1/5 completed.
# Epoch 2/5 completed.
# Epoch 3/5 completed.
# Epoch 4/5 completed.
# Epoch 5/5 completed.
# Pruning (20%) Result (Epochs=5): Initial A=81.20%, Final B=88.26%, Final A=31.74%, Forgetting=49.46%, Drift=71.8919, Prep Time=0.20s, Peak VRAM=597.43MB
#    > Epochs: 10
# Pruning 21 layers with Global Sparsity 20.0%...
# Global Sparsity Achieved: 20.00%
# Zero-Shot: 81.22% (Compression Damage: -0.02%)
# Starting Constrained Training (Method: MagnitudePruningProjector)...
# Epoch 1/10 completed.
# Epoch 2/10 completed.
# Epoch 3/10 completed.
# Epoch 4/10 completed.
# Epoch 5/10 completed.
# Epoch 6/10 completed.
# Epoch 7/10 completed.
# Epoch 8/10 completed.
# ...

# %%
# --- CELL 10: Visualization ---
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

print("\n--- Final Comparative Visualization ---")

# Robust check for results list in global scope
if 'results' in globals() and results:
    df_full = pd.DataFrame(results)

    # Identify unique epoch durations to plot separately
    if "Epochs" in df_full.columns:
        epoch_list = sorted(df_full["Epochs"].unique())
    else:
        epoch_list = ["Unknown"]
        df_full["Epochs"] = "Unknown"

    for current_epoch in epoch_list:
        print(f"\n>>> Generating Plot for {current_epoch} Epochs...")

        # Filter for current epoch
        df = df_full[df_full["Epochs"] == current_epoch].copy()

        # 1. Deduplication: Keep the LAST run for each method
        df = df.drop_duplicates(subset=['Method'], keep='last').reset_index(drop=True)

        # 2. Filter Logic
        # Exclude generic pruning, keep only 20% / 0.2
        is_pruning = df['Method'].str.contains("Pruning")
        is_pruning_20 = is_pruning & (df['Method'].str.contains("20%") | df['Method'].str.contains("0.2"))

        df_plot = df[~is_pruning | is_pruning_20].copy().reset_index(drop=True)

        if df_plot.empty:
            print(f"No results matched the filtering criteria for {current_epoch} epochs.")
            continue

        # Rename column for the legend if it exists
        if 'Task A Acc (Retention)' in df_plot.columns:
            df_plot.rename(columns={'Task A Acc (Retention)': 'Task A Final'}, inplace=True)

        plt.figure(figsize=(12, 6))

        # Basic plot parameters
        y_cols = ["Task B Acc (Plasticity)", "Task A Final"]
        # Verify columns exist
        missing_cols = [c for c in y_cols if c not in df_plot.columns]
        if missing_cols:
            print(f"Error: Missing columns in results: {missing_cols}")
        else:
            ax = df_plot.plot(
                x="Method",
                y=y_cols,
                kind="bar",
                figsize=(12, 6),
                color=['#1f77b4', '#ff7f0e'],
                width=0.7,
                rot=0
            )

            plt.title(f"Method Comparison (Epochs={current_epoch}): Plasticity (Task B) vs. Retention (Task A Final)")
            plt.ylabel("Accuracy (%)")
            plt.ylim(0, 115)
            plt.xticks(rotation=15, ha='right')
            plt.grid(axis='y', alpha=0.3)
            plt.legend(loc='lower right')

            # 3. Add Time and VRAM Annotations
            if 'Prep Time (s)' in df_plot.columns:
                n_groups = len(df_plot)
                patches = ax.patches
                # Matplotlib bar plot patch order: All bar1s, then all bar2s
                if len(patches) >= 2 * n_groups:
                    for i in range(n_groups):
                        rect_B = patches[i]
                        rect_A = patches[i + n_groups]

                        group_center = (rect_B.get_x() + rect_A.get_x() + rect_B.get_width() + rect_A.get_width()) / 2 - (rect_B.get_width() / 2)
                        max_height = max(rect_B.get_height(), rect_A.get_height())

                        # Time Metric
                        time_val = df_plot.loc[i, 'Prep Time (s)']
                        time_str = f"{time_val:.2f}s" if isinstance(time_val, (int, float)) else str(time_val)

                        # VRAM Metric
                        vram_str = ""
                        if 'Peak VRAM (MB)' in df_plot.columns:
                            vram_val = df_plot.loc[i, 'Peak VRAM (MB)']
                            vram_val_str = f"{vram_val:.2f}MB" if isinstance(vram_val, (int, float)) else str(vram_val)
                            vram_str = f"\nVRAM: {vram_val_str}"

                        # Construct Label
                        label = f"Time: {time_str}{vram_str}"

                        ax.text(
                            group_center,
                            max_height + 2,
                            label,
                            ha='center',
                            va='bottom',
                            fontsize=8,
                            fontweight='bold',
                            color='black'
                        )

            plt.tight_layout()
            plt.show()
else:
    print("No results to visualize. 'results' variable is empty or undefined.")
# Out:
# --- Final Comparative Visualization ---
#
# >>> Generating Plot for 5 Epochs...
# >>> Generating Plot for 10 Epochs...
# >>> Generating Plot for 15 Epochs...

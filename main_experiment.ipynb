# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
import os
# Update this path to match your folder name exactly
PROJECT_PATH = '/content/drive/MyDrive/Colab Notebooks/deep_learning_project'
#PROJECT_PATH = '/content/drive/MyDrive/folders/deep_learning_project'


if os.path.exists(PROJECT_PATH):
    print(f"✅ Success! Found project at: {PROJECT_PATH}")
    os.chdir(PROJECT_PATH)
else:
    print(f"❌ Error: The path '{PROJECT_PATH}' does not exist.")
# Out:
# Mounted at /content/drive
# ✅ Success! Found project at: /content/drive/MyDrive/Colab Notebooks/deep_learning_project

# %%
# --- CELL 1: Imports & Configuration ---

import torch
import time
import pandas as pd
import matplotlib.pyplot as plt
from src.data_utils import get_split_cifar10
from src.models import get_resnet18
from src.trainer import train_baseline, train_constrained, evaluate
from src.decompositions import SVDProjector, QRProjector, RSVDProjector, MagnitudePruningProjector, AdaptiveSVDProjector

# CONFIGURATION
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
BATCH_SIZE = 64

# CIFAR-10 Specifics
CLASSES = 10
EPOCHS_EXPERT = 5
TASK_A_INDICES = list(range(5))
TASK_B_INDICES = list(range(5, 10))
CHECKPOINT_PATH = "checkpoints/task_a_expert_c10.pth"

TASK_B_EPOCHS_LIST = [2,4,6,8]

results = []
print("Configuration Complete. Single Dataset (CIFAR-10) Mode.")
# Out:
# Configuration Complete. Single Dataset (CIFAR-10) Mode.

# %%
# --- CELL 2: Infrastructure & Baseline (Task A) ---
import os
os.makedirs("checkpoints", exist_ok=True)

print(f"\n=== Processing CIFAR-10 Expert ===")

# 1. Data Partitioning and Loader Initialization
print("--- Phase 1: Data Setup ---")
train_A, test_A, train_B, test_B = get_split_cifar10(BATCH_SIZE)

# 2. Task A Expert Model Training
print(f"--- Phase 2: Training Expert Model (Task A) for {EPOCHS_EXPERT} epochs ---")
model_expert = get_resnet18(num_classes=CLASSES).to(DEVICE)
# Retrieves training history for logging
model_expert, history = train_baseline(model_expert, train_A, EPOCHS_EXPERT, DEVICE)
torch.save(model_expert.state_dict(), CHECKPOINT_PATH)

# 3. Baseline Performance Evaluation
acc_A_initial = evaluate(model_expert, test_A, DEVICE, task_classes=TASK_A_INDICES)
print(f"Final Training Accuracy: {history['accuracy'][-1]:.2f}%")
print(f"CIFAR-10 Task A Expert Accuracy: {acc_A_initial:.2f}%")
# Out:
# === Processing CIFAR-10 Expert ===
# --- Phase 1: Data Setup ---
# --- Phase 2: Training Expert Model (Task A) for 5 epochs ---
# Starting Baseline Training (Task A) - Optimized Adam...
# Epoch 1/5 | Loss: 0.8884 | Acc: 64.78% | LR: 0.000905
# Epoch 2/5 | Loss: 0.5853 | Acc: 77.82% | LR: 0.000655
# Epoch 3/5 | Loss: 0.4266 | Acc: 84.06% | LR: 0.000345
# Epoch 4/5 | Loss: 0.2825 | Acc: 89.79% | LR: 0.000095
# Epoch 5/5 | Loss: 0.1467 | Acc: 94.94% | LR: 0.000000
# Final Training Accuracy: 94.94%
# CIFAR-10 Task A Expert Accuracy: 87.30%

# %%
# --- CELL 3: Experiment - Naive Baseline ---
print("\n--- Experiment: Naive Baseline ---")

train_A, test_A, train_B, test_B = get_split_cifar10(BATCH_SIZE)

# Assessment of initial Task A accuracy
model_ref = get_resnet18(num_classes=CLASSES).to(DEVICE)
model_ref.load_state_dict(torch.load(CHECKPOINT_PATH))
acc_A_initial = evaluate(model_ref, test_A, DEVICE, task_classes=TASK_A_INDICES)

for epochs_b in TASK_B_EPOCHS_LIST:
    print(f"\n   > Epochs: {epochs_b}")

    # Resets model state to the pre-trained expert
    model_current = get_resnet18(num_classes=CLASSES).to(DEVICE)
    model_current.load_state_dict(torch.load(CHECKPOINT_PATH))

    # Naive Training (Unconstrained Fine-tuning)
    model_current, history = train_baseline(model_current, train_B, epochs_b, DEVICE)

    # Computes final performance metrics
    acc_A_final = evaluate(model_current, test_A, DEVICE, task_classes=TASK_A_INDICES)
    acc_B_final = evaluate(model_current, test_B, DEVICE, task_classes=TASK_B_INDICES)
    global_acc = (acc_A_final + acc_B_final) / 2
    forgetting = acc_A_initial - acc_A_final

    train_acc = history['accuracy'][-1]

    results.append({
        "Method": "Naive",
        "Hyperparam": "N/A",
        "Epochs": epochs_b,
        "Global Acc": global_acc,
        "Task A Acc (Retention)": acc_A_final,
        "Task B Acc (Plasticity)": acc_B_final,
        "Forgetting": forgetting,
        "Train Acc": train_acc,
        "Peak VRAM (MB)": 0,
        "Prep Time (s)": 0
    })
    print(f"Result: Global={global_acc:.2f}%, A={acc_A_final:.2f}%, B={acc_B_final:.2f}%, TrainAcc={train_acc:.2f}%")
# Out:
# --- Experiment: Naive Baseline ---
#
#    > Epochs: 2
# Starting Baseline Training (Task A) - Optimized Adam...
# Epoch 1/2 | Loss: 0.6189 | Acc: 81.52% | LR: 0.000500
# Epoch 2/2 | Loss: 0.2338 | Acc: 91.82% | LR: 0.000000
# Result: Global=49.99%, A=11.10%, B=88.88%, TrainAcc=91.82%
#
#    > Epochs: 4
# Starting Baseline Training (Task A) - Optimized Adam...
# Epoch 1/4 | Loss: 0.6027 | Acc: 82.02% | LR: 0.000854
# Epoch 2/4 | Loss: 0.2777 | Acc: 90.10% | LR: 0.000500
# Epoch 3/4 | Loss: 0.1763 | Acc: 93.86% | LR: 0.000146
# Epoch 4/4 | Loss: 0.0831 | Acc: 97.22% | LR: 0.000000
# Result: Global=57.92%, A=21.40%, B=94.44%, TrainAcc=97.22%
#
#    > Epochs: 6
# Starting Baseline Training (Task A) - Optimized Adam...
# Epoch 1/6 | Loss: 0.6037 | Acc: 81.80% | LR: 0.000933
# Epoch 2/6 | Loss: 0.2833 | Acc: 89.89% | LR: 0.000750
# Epoch 3/6 | Loss: 0.2005 | Acc: 92.87% | LR: 0.000500
# Epoch 4/6 | Loss: 0.1323 | Acc: 95.32% | LR: 0.000250
# Epoch 5/6 | Loss: 0.0565 | Acc: 98.12% | LR: 0.000067
# Epoch 6/6 | Loss: 0.0243 | Acc: 99.24% | LR: 0.000000
# Result: Global=57.32%, A=20.04%, B=94.60%, TrainAcc=99.24%
#
#    > Epochs: 8
# Starting Baseline Training (Task A) - Optimized Adam...
# Epoch 1/8 | Loss: 0.6274 | Acc: 80.82% | LR: 0.000962
# Epoch 2/8 | Loss: 0.2798 | Acc: 90.06% | LR: 0.000854
# Epoch 3/8 | Loss: 0.2201 | Acc: 92.24% | LR: 0.000691
# Epoch 4/8 | Loss: 0.1634 | Acc: 94.37% | LR: 0.000500
# Epoch 5/8 | Loss: 0.1048 | Acc: 96.32% | LR: 0.000309
# Epoch 6/8 | Loss: 0.0536 | Acc: 98.07% | LR: 0.000146
# Epoch 7/8 | Loss: 0.0210 | Acc: 99.34% | LR: 0.000038
# Epoch 8/8 | Loss: 0.0076 | Acc: 99.83% | LR: 0.000000
# Result: Global=54.72%, A=14.80%, B=94.64%, TrainAcc=99.83%

# %%
# --- CELL EXPERIMENT: Standard SVD ---
print("\n--- Experiment: Standard SVD ---")

hyperparams = [ 0.95]

train_A, test_A, train_B, test_B = get_split_cifar10(BATCH_SIZE)

# Establishes baseline reference for comparison
model_ref = get_resnet18(num_classes=CLASSES).to(DEVICE)
model_ref.load_state_dict(torch.load(CHECKPOINT_PATH))
acc_A_initial = evaluate(model_ref, test_A, DEVICE, task_classes=TASK_A_INDICES)

for hp in hyperparams:
    print(f"\n   >>> Threshold: {hp}")

    # Phase A: Subspace Computation (Executed once per hyperparameter setting)
    prep_time = 0
    peak_vram = 0

    # Instantiates the projector with the current hyperparameter
    # Configures the projector instance
    projector = SVDProjector(rank_threshold=hp)


    if torch.cuda.is_available():
        torch.cuda.reset_peak_memory_stats()
        torch.cuda.empty_cache()

    start_time = time.time()
    projector.compute_subspaces(model_ref)

    if torch.cuda.is_available():
        peak_vram = torch.cuda.max_memory_allocated() / (1024 ** 2)
    prep_time = time.time() - start_time
    print(f"      Subspace computed in {prep_time:.2f}s")


    for epochs_b in TASK_B_EPOCHS_LIST:
        print(f"      > Epochs: {epochs_b}")

        # Resets model state to the pre-trained expert
        model_current = get_resnet18(num_classes=CLASSES).to(DEVICE)
        model_current.load_state_dict(torch.load(CHECKPOINT_PATH))

        # Records initial weights to calculate subsequent drift
        w_start = {name: param.detach().cpu().clone() for name, param in model_current.named_parameters()}

        # Evaluates zero-shot accuracy to quantify compression damage
        acc_A_zero = evaluate(model_current, test_A, DEVICE, task_classes=TASK_A_INDICES)
        compression_damage = acc_A_initial - acc_A_zero

        # Performs constrained training on Task B
        model_current, history = train_constrained(model_current, train_B, epochs_b, DEVICE, projector)

        # Computes final performance metrics
        acc_A_final = evaluate(model_current, test_A, DEVICE, task_classes=TASK_A_INDICES)
        acc_B_final = evaluate(model_current, test_B, DEVICE, task_classes=TASK_B_INDICES)

        global_acc = (acc_A_final + acc_B_final) / 2
        forgetting = acc_A_zero - acc_A_final
        train_acc = history['accuracy'][-1]

        drift_sq = 0.0
        for name, param in model_current.named_parameters():
                if name in w_start:
                    diff = param.detach().cpu() - w_start[name]
                    drift_sq += torch.sum(diff ** 2).item()
        weight_drift = drift_sq ** 0.5

        results.append({
            "Method": "SVD",
            "Hyperparam": hp,
            "Epochs": epochs_b,
            "Global Acc": global_acc,
            "Task A Acc (Retention)": acc_A_final,
            "Task B Acc (Plasticity)": acc_B_final,
            "Train Acc": train_acc,
            "Zero-Shot A": acc_A_zero,
            "Compression Damage": compression_damage,
            "Forgetting": forgetting,
            "Peak VRAM (MB)": peak_vram,
            "Weight Drift": weight_drift,
            "Prep Time (s)": prep_time
        })
        print(f"Result: Global={global_acc:.2f}%, A={acc_A_final:.2f}%, B={acc_B_final:.2f}%, Train={train_acc:.2f}%")
# Out:
# --- Experiment: Standard SVD ---
#
#    >>> Threshold: 0.95
#       Subspace computed in 0.23s
#       > Epochs: 2
# Starting Constrained Training (Method: SVDProjector)...
# Epoch 1/2 | Loss: 0.6736 | Acc: 82.11%
# Epoch 2/2 | Loss: 0.2761 | Acc: 90.32%
# Result: Global=59.81%, A=34.42%, B=85.20%, Train=90.32%
#       > Epochs: 4
# Starting Constrained Training (Method: SVDProjector)...
# Epoch 1/4 | Loss: 0.6689 | Acc: 81.80%
# Epoch 2/4 | Loss: 0.2706 | Acc: 90.35%
# Epoch 3/4 | Loss: 0.2180 | Acc: 92.30%
# Epoch 4/4 | Loss: 0.1764 | Acc: 93.54%
# Result: Global=66.10%, A=40.38%, B=91.82%, Train=93.54%
#       > Epochs: 6
# Starting Constrained Training (Method: SVDProjector)...
# Epoch 1/6 | Loss: 0.6851 | Acc: 81.60%
# Epoch 2/6 | Loss: 0.2723 | Acc: 90.24%
# Epoch 3/6 | Loss: 0.2205 | Acc: 92.38%
# Epoch 4/6 | Loss: 0.1762 | Acc: 93.80%
# Epoch 5/6 | Loss: 0.1498 | Acc: 94.64%
# Epoch 6/6 | Loss: 0.1336 | Acc: 95.22%
# Result: Global=64.60%, A=37.86%, B=91.34%, Train=95.22%
#       > Epochs: 8
# Starting Constrained Training (Method: SVDProjector)...
# Epoch 1/8 | Loss: 0.6729 | Acc: 81.93%
# Epoch 2/8 | Loss: 0.2767 | Acc: 90.13%
# Epoch 3/8 | Loss: 0.2156 | Acc: 92.30%
# Epoch 4/8 | Loss: 0.1739 | Acc: 93.72%
# Epoch 5/8 | Loss: 0.1471 | Acc: 94.66%
# Epoch 6/8 | Loss: 0.1253 | Acc: 95.51%
# Epoch 7/8 | Loss: 0.1091 | Acc: 96.21%
# Epoch 8/8 | Loss: 0.0950 | Acc: 96.67%
# Result: Global=60.09%, A=29.48%, B=90.70%, Train=96.67%

# %%
# --- CELL EXPERIMENT: Adaptive SVD ---
print("\n--- Experiment: Adaptive SVD ---")

hyperparams = [ 0.4]

train_A, test_A, train_B, test_B = get_split_cifar10(BATCH_SIZE)

# Establishes baseline reference for comparison
model_ref = get_resnet18(num_classes=CLASSES).to(DEVICE)
model_ref.load_state_dict(torch.load(CHECKPOINT_PATH))
acc_A_initial = evaluate(model_ref, test_A, DEVICE, task_classes=TASK_A_INDICES)

for hp in hyperparams:
    print(f"\n   >>> MRR: {hp}")

    # Phase A: Subspace Computation (Executed once per hyperparameter setting)
    prep_time = 0
    peak_vram = 0

    # Instantiates the projector with the current hyperparameter
    # Configures the projector instance
    projector = AdaptiveSVDProjector(mrr=hp, trr=0.95)


    if torch.cuda.is_available():
        torch.cuda.reset_peak_memory_stats()
        torch.cuda.empty_cache()

    start_time = time.time()
    projector.compute_subspaces(model_ref, test_A, DEVICE)

    if torch.cuda.is_available():
        peak_vram = torch.cuda.max_memory_allocated() / (1024 ** 2)
    prep_time = time.time() - start_time
    print(f"      Subspace computed in {prep_time:.2f}s")


    for epochs_b in TASK_B_EPOCHS_LIST:
        print(f"      > Epochs: {epochs_b}")

        # Resets model state to the pre-trained expert
        model_current = get_resnet18(num_classes=CLASSES).to(DEVICE)
        model_current.load_state_dict(torch.load(CHECKPOINT_PATH))

        # Records initial weights to calculate subsequent drift
        w_start = {name: param.detach().cpu().clone() for name, param in model_current.named_parameters()}

        # Evaluates zero-shot accuracy to quantify compression damage
        acc_A_zero = evaluate(model_current, test_A, DEVICE, task_classes=TASK_A_INDICES)
        compression_damage = acc_A_initial - acc_A_zero

        # Performs constrained training on Task B
        model_current, history = train_constrained(model_current, train_B, epochs_b, DEVICE, projector)

        # Computes final performance metrics
        acc_A_final = evaluate(model_current, test_A, DEVICE, task_classes=TASK_A_INDICES)
        acc_B_final = evaluate(model_current, test_B, DEVICE, task_classes=TASK_B_INDICES)

        global_acc = (acc_A_final + acc_B_final) / 2
        forgetting = acc_A_zero - acc_A_final
        train_acc = history['accuracy'][-1]

        drift_sq = 0.0
        for name, param in model_current.named_parameters():
                if name in w_start:
                    diff = param.detach().cpu() - w_start[name]
                    drift_sq += torch.sum(diff ** 2).item()
        weight_drift = drift_sq ** 0.5

        results.append({
            "Method": "Adaptive SVD",
            "Hyperparam": hp,
            "Epochs": epochs_b,
            "Global Acc": global_acc,
            "Task A Acc (Retention)": acc_A_final,
            "Task B Acc (Plasticity)": acc_B_final,
            "Train Acc": train_acc,
            "Zero-Shot A": acc_A_zero,
            "Compression Damage": compression_damage,
            "Forgetting": forgetting,
            "Peak VRAM (MB)": peak_vram,
            "Weight Drift": weight_drift,
            "Prep Time (s)": prep_time
        })
        print(f"Result: Global={global_acc:.2f}%, A={acc_A_final:.2f}%, B={acc_B_final:.2f}%, Train={train_acc:.2f}%")
# Out:
# --- Experiment: Adaptive SVD ---
#
#    >>> MRR: 0.4
# Adaptive SVD: Avg Importance = 0.3976 (over 13 matching layers)
#       Subspace computed in 0.26s
#       > Epochs: 2
# Starting Constrained Training (Method: AdaptiveSVDProjector)...
# Epoch 1/2 | Loss: 0.6852 | Acc: 81.62%
# Epoch 2/2 | Loss: 0.2680 | Acc: 90.58%
# Result: Global=65.16%, A=44.34%, B=85.98%, Train=90.58%
#       > Epochs: 4
# Starting Constrained Training (Method: AdaptiveSVDProjector)...
# Epoch 1/4 | Loss: 0.6840 | Acc: 81.61%
# Epoch 2/4 | Loss: 0.2727 | Acc: 90.23%
# Epoch 3/4 | Loss: 0.2104 | Acc: 92.55%
# Epoch 4/4 | Loss: 0.1806 | Acc: 93.64%
# Result: Global=64.72%, A=39.92%, B=89.52%, Train=93.64%
#       > Epochs: 6
# Starting Constrained Training (Method: AdaptiveSVDProjector)...
# Epoch 1/6 | Loss: 0.6738 | Acc: 81.93%
# Epoch 2/6 | Loss: 0.2636 | Acc: 90.73%
# Epoch 3/6 | Loss: 0.2125 | Acc: 92.29%
# Epoch 4/6 | Loss: 0.1754 | Acc: 93.90%
# Epoch 5/6 | Loss: 0.1452 | Acc: 94.85%
# Epoch 6/6 | Loss: 0.1304 | Acc: 95.36%
# Result: Global=61.68%, A=34.00%, B=89.36%, Train=95.36%
#       > Epochs: 8
# Starting Constrained Training (Method: AdaptiveSVDProjector)...
# Epoch 1/8 | Loss: 0.6749 | Acc: 81.81%
# Epoch 2/8 | Loss: 0.2707 | Acc: 90.24%
# Epoch 3/8 | Loss: 0.2115 | Acc: 92.61%
# Epoch 4/8 | Loss: 0.1756 | Acc: 93.84%
# Epoch 5/8 | Loss: 0.1443 | Acc: 94.84%
# Epoch 6/8 | Loss: 0.1294 | Acc: 95.34%
# Epoch 7/8 | Loss: 0.0977 | Acc: 96.64%
# Epoch 8/8 | Loss: 0.0974 | Acc: 96.56%
# Result: Global=58.55%, A=29.40%, B=87.70%, Train=96.56%

# %%
# --- CELL EXPERIMENT: Randomized SVD ---
print("\n--- Experiment: Randomized SVD ---")

hyperparams = [0.4, 0.5, 0.6]

train_A, test_A, train_B, test_B = get_split_cifar10(BATCH_SIZE)

# Establishes baseline reference for comparison
model_ref = get_resnet18(num_classes=CLASSES).to(DEVICE)
model_ref.load_state_dict(torch.load(CHECKPOINT_PATH))
acc_A_initial = evaluate(model_ref, test_A, DEVICE, task_classes=TASK_A_INDICES)

for hp in hyperparams:
    print(f"\n   >>> Rank Fraction: {hp}")

    # Phase A: Subspace Computation (Executed once per hyperparameter setting)
    prep_time = 0
    peak_vram = 0

    # Instantiates the projector with the current hyperparameter
    # Configures the projector instance
    projector = RSVDProjector(rank_fraction=hp, p=10, q=2)


    if torch.cuda.is_available():
        torch.cuda.reset_peak_memory_stats()
        torch.cuda.empty_cache()

    start_time = time.time()
    projector.compute_subspaces(model_ref)

    if torch.cuda.is_available():
        peak_vram = torch.cuda.max_memory_allocated() / (1024 ** 2)
    prep_time = time.time() - start_time
    print(f"      Subspace computed in {prep_time:.2f}s")


    for epochs_b in TASK_B_EPOCHS_LIST:
        print(f"      > Epochs: {epochs_b}")

        # Resets model state to the pre-trained expert
        model_current = get_resnet18(num_classes=CLASSES).to(DEVICE)
        model_current.load_state_dict(torch.load(CHECKPOINT_PATH))

        # Records initial weights to calculate subsequent drift
        w_start = {name: param.detach().cpu().clone() for name, param in model_current.named_parameters()}

        # Evaluates zero-shot accuracy to quantify compression damage
        acc_A_zero = evaluate(model_current, test_A, DEVICE, task_classes=TASK_A_INDICES)
        compression_damage = acc_A_initial - acc_A_zero

        # Performs constrained training on Task B
        model_current, history = train_constrained(model_current, train_B, epochs_b, DEVICE, projector)

        # Computes final performance metrics
        acc_A_final = evaluate(model_current, test_A, DEVICE, task_classes=TASK_A_INDICES)
        acc_B_final = evaluate(model_current, test_B, DEVICE, task_classes=TASK_B_INDICES)

        global_acc = (acc_A_final + acc_B_final) / 2
        forgetting = acc_A_zero - acc_A_final
        train_acc = history['accuracy'][-1]

        drift_sq = 0.0
        for name, param in model_current.named_parameters():
                if name in w_start:
                    diff = param.detach().cpu() - w_start[name]
                    drift_sq += torch.sum(diff ** 2).item()
        weight_drift = drift_sq ** 0.5

        results.append({
            "Method": "RSVD",
            "Hyperparam": hp,
            "Epochs": epochs_b,
            "Global Acc": global_acc,
            "Task A Acc (Retention)": acc_A_final,
            "Task B Acc (Plasticity)": acc_B_final,
            "Train Acc": train_acc,
            "Zero-Shot A": acc_A_zero,
            "Compression Damage": compression_damage,
            "Forgetting": forgetting,
            "Peak VRAM (MB)": peak_vram,
            "Weight Drift": weight_drift,
            "Prep Time (s)": prep_time
        })
        print(f"Result: Global={global_acc:.2f}%, A={acc_A_final:.2f}%, B={acc_B_final:.2f}%, Train={train_acc:.2f}%")
# Out:
# --- Experiment: Randomized SVD ---
#
#    >>> Rank Fraction: 0.4
#       Subspace computed in 0.21s
#       > Epochs: 2
# Starting Constrained Training (Method: RSVDProjector)...
# Epoch 1/2 | Loss: 0.6544 | Acc: 81.43%
# Epoch 2/2 | Loss: 0.2849 | Acc: 89.82%
# Result: Global=66.57%, A=46.38%, B=86.76%, Train=89.82%
#       > Epochs: 4
# Starting Constrained Training (Method: RSVDProjector)...
# Epoch 1/4 | Loss: 0.6655 | Acc: 81.52%
# Epoch 2/4 | Loss: 0.2794 | Acc: 89.96%
# Epoch 3/4 | Loss: 0.2335 | Acc: 91.80%
# Epoch 4/4 | Loss: 0.1857 | Acc: 93.38%
# Result: Global=68.61%, A=45.24%, B=91.98%, Train=93.38%
#       > Epochs: 6
# Starting Constrained Training (Method: RSVDProjector)...
# Epoch 1/6 | Loss: 0.6412 | Acc: 82.20%
# Epoch 2/6 | Loss: 0.2873 | Acc: 89.91%
# Epoch 3/6 | Loss: 0.2219 | Acc: 92.21%
# Epoch 4/6 | Loss: 0.1912 | Acc: 93.19%
# Epoch 5/6 | Loss: 0.1617 | Acc: 94.34%
# Epoch 6/6 | Loss: 0.1354 | Acc: 95.24%
# Result: Global=67.17%, A=44.58%, B=89.76%, Train=95.24%
#       > Epochs: 8
# Starting Constrained Training (Method: RSVDProjector)...
# Epoch 1/8 | Loss: 0.6756 | Acc: 80.57%
# Epoch 2/8 | Loss: 0.2880 | Acc: 89.58%
# Epoch 3/8 | Loss: 0.2245 | Acc: 91.96%
# Epoch 4/8 | Loss: 0.1860 | Acc: 93.37%
# Epoch 5/8 | Loss: 0.1591 | Acc: 94.32%
# Epoch 6/8 | Loss: 0.1341 | Acc: 95.37%
# Epoch 7/8 | Loss: 0.1103 | Acc: 96.12%
# Epoch 8/8 | Loss: 0.1001 | Acc: 96.53%
# Result: Global=67.11%, A=42.46%, B=91.76%, Train=96.53%
#
#    >>> Rank Fraction: 0.5
#       Subspace computed in 0.20s
#       > Epochs: 2
# Starting Constrained Training (Method: RSVDProjector)...
# Epoch 1/2 | Loss: 0.6564 | Acc: 81.74%
# Epoch 2/2 | Loss: 0.2831 | Acc: 90.04%
# Result: Global=67.50%, A=46.96%, B=88.04%, Train=90.04%
#       > Epochs: 4
# Starting Constrained Training (Method: RSVDProjector)...
# Epoch 1/4 | Loss: 0.6604 | Acc: 81.55%
# Epoch 2/4 | Loss: 0.2772 | Acc: 90.12%
# Epoch 3/4 | Loss: 0.2274 | Acc: 91.93%
# Epoch 4/4 | Loss: 0.1846 | Acc: 93.58%
# Result: Global=65.76%, A=40.14%, B=91.38%, Train=93.58%
#       > Epochs: 6
# Starting Constrained Training (Method: RSVDProjector)...
# Epoch 1/6 | Loss: 0.6720 | Acc: 81.32%
# Epoch 2/6 | Loss: 0.2812 | Acc: 89.96%
# Epoch 3/6 | Loss: 0.2187 | Acc: 92.36%
# Epoch 4/6 | Loss: 0.1831 | Acc: 93.47%
# Epoch 5/6 | Loss: 0.1525 | Acc: 94.77%
# Epoch 6/6 | Loss: 0.1338 | Acc: 95.23%
# Result: Global=62.87%, A=34.68%, B=91.06%, Train=95.23%
#       > Epochs: 8
# Starting Constrained Training (Method: RSVDProjector)...
# Epoch 1/8 | Loss: 0.6512 | Acc: 82.17%
# Epoch 2/8 | Loss: 0.2732 | Acc: 90.36%
# Epoch 3/8 | Loss: 0.2193 | Acc: 92.28%
# Epoch 4/8 | Loss: 0.1856 | Acc: 93.57%
# Epoch 5/8 | Loss: 0.1595 | Acc: 94.26%
# Epoch 6/8 | Loss: 0.1313 | Acc: 95.28%
# Epoch 7/8 | Loss: 0.1078 | Acc: 96.26%
# Epoch 8/8 | Loss: 0.0978 | Acc: 96.56%
# Result: Global=64.86%, A=36.96%, B=92.76%, Train=96.56%
#
#    >>> Rank Fraction: 0.6
#       Subspace computed in 0.23s
#       > Epochs: 2
# Starting Constrained Training (Method: RSVDProjector)...
# Epoch 1/2 | Loss: 0.6721 | Acc: 81.28%
# Epoch 2/2 | Loss: 0.2840 | Acc: 89.90%
# Result: Global=66.89%, A=44.82%, B=88.96%, Train=89.90%
#       > Epochs: 4
# Starting Constrained Training (Method: RSVDProjector)...
# Epoch 1/4 | Loss: 0.6646 | Acc: 81.31%
# Epoch 2/4 | Loss: 0.2770 | Acc: 90.11%
# Epoch 3/4 | Loss: 0.2305 | Acc: 91.81%
# Epoch 4/4 | Loss: 0.1824 | Acc: 93.35%
# Result: Global=60.61%, A=30.32%, B=90.90%, Train=93.35%
#       > Epochs: 6
# Starting Constrained Training (Method: RSVDProjector)...
# Epoch 1/6 | Loss: 0.6492 | Acc: 82.10%
# Epoch 2/6 | Loss: 0.2788 | Acc: 90.27%
# Epoch 3/6 | Loss: 0.2212 | Acc: 92.22%
# Epoch 4/6 | Loss: 0.1836 | Acc: 93.50%
# Epoch 5/6 | Loss: 0.1575 | Acc: 94.42%
# Epoch 6/6 | Loss: 0.1272 | Acc: 95.48%
# Result: Global=66.80%, A=44.22%, B=89.38%, Train=95.48%
#       > Epochs: 8
# Starting Constrained Training (Method: RSVDProjector)...
# Epoch 1/8 | Loss: 0.6554 | Acc: 81.69%
# Epoch 2/8 | Loss: 0.2794 | Acc: 90.26%
# Epoch 3/8 | Loss: 0.2301 | Acc: 91.90%
# Epoch 4/8 | Loss: 0.1830 | Acc: 93.42%
# Epoch 5/8 | Loss: 0.1515 | Acc: 94.72%
# Epoch 6/8 | Loss: 0.1339 | Acc: 95.25%
# Epoch 7/8 | Loss: 0.1081 | Acc: 96.17%
# Epoch 8/8 | Loss: 0.1026 | Acc: 96.19%
# Result: Global=67.92%, A=45.12%, B=90.72%, Train=96.19%

# %%
# --- CELL EXPERIMENT: Pivoted QR ---
print("\n--- Experiment: Pivoted QR ---")
hyperparams = [0.4, 0.5, 0.6]

train_A, test_A, train_B, test_B = get_split_cifar10(BATCH_SIZE)

# Establishes baseline reference for comparison
model_ref = get_resnet18(num_classes=CLASSES).to(DEVICE)
model_ref.load_state_dict(torch.load(CHECKPOINT_PATH))
acc_A_initial = evaluate(model_ref, test_A, DEVICE, task_classes=TASK_A_INDICES)

for hp in hyperparams:
    print(f"\n   >>> Rank Fraction: {hp}")

    # Phase A: Subspace Computation (Executed once per hyperparameter setting)
    prep_time = 0
    peak_vram = 0

    # Instantiates the projector with the current hyperparameter
    # Configures the projector instance
    projector = QRProjector(rank_fraction=hp)


    if torch.cuda.is_available():
        torch.cuda.reset_peak_memory_stats()
        torch.cuda.empty_cache()

    start_time = time.time()
    projector.compute_subspaces(model_ref, device=DEVICE)

    if torch.cuda.is_available():
        peak_vram = torch.cuda.max_memory_allocated() / (1024 ** 2)
    prep_time = time.time() - start_time
    print(f"      QR Subspace computed in {prep_time:.2f}s")


    for epochs_b in TASK_B_EPOCHS_LIST:
        print(f"      > Epochs: {epochs_b}")

        # Resets model state to the pre-trained expert
        model_current = get_resnet18(num_classes=CLASSES).to(DEVICE)
        model_current.load_state_dict(torch.load(CHECKPOINT_PATH))

        # Records initial weights to calculate subsequent drift
        w_start = {name: param.detach().cpu().clone() for name, param in model_current.named_parameters()}

        # Evaluates zero-shot accuracy to quantify compression damage
        acc_A_zero = evaluate(model_current, test_A, DEVICE, task_classes=TASK_A_INDICES)
        compression_damage = acc_A_initial - acc_A_zero

        # Performs constrained training on Task B
        model_current, history = train_constrained(model_current, train_B, epochs_b, DEVICE, projector)

        # Computes final performance metrics
        acc_A_final = evaluate(model_current, test_A, DEVICE, task_classes=TASK_A_INDICES)
        acc_B_final = evaluate(model_current, test_B, DEVICE, task_classes=TASK_B_INDICES)

        global_acc = (acc_A_final + acc_B_final) / 2
        forgetting = acc_A_zero - acc_A_final
        train_acc = history['accuracy'][-1]

        drift_sq = 0.0
        for name, param in model_current.named_parameters():
                if name in w_start:
                    diff = param.detach().cpu() - w_start[name]
                    drift_sq += torch.sum(diff ** 2).item()
        weight_drift = drift_sq ** 0.5

        results.append({
            "Method": "Pivoted QR",
            "Hyperparam": hp,
            "Epochs": epochs_b,
            "Global Acc": global_acc,
            "Task A Acc (Retention)": acc_A_final,
            "Task B Acc (Plasticity)": acc_B_final,
            "Train Acc": train_acc,
            "Zero-Shot A": acc_A_zero,
            "Compression Damage": compression_damage,
            "Forgetting": forgetting,
            "Peak VRAM (MB)": peak_vram,
            "Weight Drift": weight_drift,
            "Prep Time (s)": prep_time
        })
        print(f"Result: Global={global_acc:.2f}%, A={acc_A_final:.2f}%, B={acc_B_final:.2f}%, Train={train_acc:.2f}%")
# Out:
# --- Experiment: Pivoted QR ---
#
#    >>> Rank Fraction: 0.4
# Computing QR subspaces (Pivoted) using Scipy...
#       QR Subspace computed in 1.88s
#       > Epochs: 2
# Starting Constrained Training (Method: QRProjector)...
# Epoch 1/2 | Loss: 0.7586 | Acc: 80.06%
# Epoch 2/2 | Loss: 0.2866 | Acc: 90.02%
# Result: Global=51.22%, A=15.64%, B=86.80%, Train=90.02%
#       > Epochs: 4
# Starting Constrained Training (Method: QRProjector)...
# Epoch 1/4 | Loss: 0.7291 | Acc: 81.26%
# Epoch 2/4 | Loss: 0.2804 | Acc: 90.28%
# Epoch 3/4 | Loss: 0.2156 | Acc: 92.45%
# Epoch 4/4 | Loss: 0.1794 | Acc: 93.73%
# Result: Global=54.40%, A=18.60%, B=90.20%, Train=93.73%
#       > Epochs: 6
# Starting Constrained Training (Method: QRProjector)...
# Epoch 1/6 | Loss: 0.7418 | Acc: 80.49%
# Epoch 2/6 | Loss: 0.2782 | Acc: 90.23%
# Epoch 3/6 | Loss: 0.2177 | Acc: 92.36%
# Epoch 4/6 | Loss: 0.1809 | Acc: 93.74%
# Epoch 5/6 | Loss: 0.1558 | Acc: 94.61%
# Epoch 6/6 | Loss: 0.1279 | Acc: 95.58%
# Result: Global=48.37%, A=8.32%, B=88.42%, Train=95.58%
#       > Epochs: 8
# Starting Constrained Training (Method: QRProjector)...
# Epoch 1/8 | Loss: 0.7367 | Acc: 80.78%
# Epoch 2/8 | Loss: 0.2779 | Acc: 90.22%
# Epoch 3/8 | Loss: 0.2175 | Acc: 92.47%
# Epoch 4/8 | Loss: 0.1819 | Acc: 93.46%
# Epoch 5/8 | Loss: 0.1518 | Acc: 94.62%
# Epoch 6/8 | Loss: 0.1289 | Acc: 95.43%
# Epoch 7/8 | Loss: 0.1185 | Acc: 95.72%
# Epoch 8/8 | Loss: 0.0976 | Acc: 96.49%
# Result: Global=50.30%, A=11.02%, B=89.58%, Train=96.49%
#
#    >>> Rank Fraction: 0.5
# Computing QR subspaces (Pivoted) using Scipy...
#       QR Subspace computed in 1.79s
#       > Epochs: 2
# Starting Constrained Training (Method: QRProjector)...
# Epoch 1/2 | Loss: 0.8284 | Acc: 79.59%
# Epoch 2/2 | Loss: 0.3202 | Acc: 89.80%
# Result: Global=47.87%, A=6.24%, B=89.50%, Train=89.80%
#       > Epochs: 4
# Starting Constrained Training (Method: QRProjector)...
# Epoch 1/4 | Loss: 0.8355 | Acc: 79.64%
# Epoch 2/4 | Loss: 0.3093 | Acc: 90.14%
# Epoch 3/4 | Loss: 0.2515 | Acc: 91.97%
# Epoch 4/4 | Loss: 0.2078 | Acc: 93.52%
# Result: Global=45.78%, A=4.08%, B=87.48%, Train=93.52%
#       > Epochs: 6
# Starting Constrained Training (Method: QRProjector)...
# Epoch 1/6 | Loss: 0.8153 | Acc: 79.91%
# Epoch 2/6 | Loss: 0.3172 | Acc: 89.92%
# Epoch 3/6 | Loss: 0.2404 | Acc: 92.24%
# Epoch 4/6 | Loss: 0.2067 | Acc: 93.55%
# Epoch 5/6 | Loss: 0.1915 | Acc: 93.88%
# Epoch 6/6 | Loss: 0.1654 | Acc: 94.96%
# Result: Global=43.04%, A=3.46%, B=82.62%, Train=94.96%
#       > Epochs: 8
# Starting Constrained Training (Method: QRProjector)...
# Epoch 1/8 | Loss: 0.8357 | Acc: 79.02%
# Epoch 2/8 | Loss: 0.3087 | Acc: 90.14%
# Epoch 3/8 | Loss: 0.2482 | Acc: 92.01%
# Epoch 4/8 | Loss: 0.2112 | Acc: 93.20%
# Epoch 5/8 | Loss: 0.1907 | Acc: 94.00%
# Epoch 6/8 | Loss: 0.1667 | Acc: 94.90%
# Epoch 7/8 | Loss: 0.1646 | Acc: 95.36%
# Epoch 8/8 | Loss: 0.1391 | Acc: 96.08%
# Result: Global=48.17%, A=4.56%, B=91.78%, Train=96.08%
#
#    >>> Rank Fraction: 0.6
# Computing QR subspaces (Pivoted) using Scipy...
#       QR Subspace computed in 2.46s
#       > Epochs: 2
# Starting Constrained Training (Method: QRProjector)...
# Epoch 1/2 | Loss: 0.8632 | Acc: 78.96%
# Epoch 2/2 | Loss: 0.3236 | Acc: 90.02%
# Result: Global=47.65%, A=4.24%, B=91.06%, Train=90.02%
#       > Epochs: 4
# Starting Constrained Training (Method: QRProjector)...
# Epoch 1/4 | Loss: 0.8973 | Acc: 78.86%
# Epoch 2/4 | Loss: 0.3441 | Acc: 89.58%
# Epoch 3/4 | Loss: 0.3025 | Acc: 91.44%
# Epoch 4/4 | Loss: 0.2812 | Acc: 92.40%
# Result: Global=47.72%, A=5.24%, B=90.20%, Train=92.40%
#       > Epochs: 6
# Starting Constrained Training (Method: QRProjector)...
# Epoch 1/6 | Loss: 0.8792 | Acc: 79.64%
# Epoch 2/6 | Loss: 0.3377 | Acc: 89.96%
# Epoch 3/6 | Loss: 0.3139 | Acc: 91.26%
# Epoch 4/6 | Loss: 0.2832 | Acc: 92.40%
# Epoch 5/6 | Loss: 0.2238 | Acc: 93.68%
# Epoch 6/6 | Loss: 0.1876 | Acc: 94.65%
# Result: Global=47.56%, A=5.76%, B=89.36%, Train=94.65%
#       > Epochs: 8
# Starting Constrained Training (Method: QRProjector)...
# Epoch 1/8 | Loss: 0.8626 | Acc: 79.27%
# Epoch 2/8 | Loss: 0.3265 | Acc: 89.94%
# Epoch 3/8 | Loss: 0.2754 | Acc: 91.98%
# Epoch 4/8 | Loss: 0.2848 | Acc: 92.07%
# Epoch 5/8 | Loss: 0.2322 | Acc: 93.67%
# Epoch 6/8 | Loss: 0.1903 | Acc: 94.58%
# Epoch 7/8 | Loss: 0.1587 | Acc: 95.45%
# Epoch 8/8 | Loss: 0.1433 | Acc: 95.80%
# Result: Global=48.30%, A=5.26%, B=91.34%, Train=95.80%

# %%
# --- CELL EXPERIMENT: Global Magnitude Pruning ---
print("\n--- Experiment: Global Magnitude Pruning ---")
sparsity_targets = [0.2]

train_A, test_A, train_B, test_B = get_split_cifar10(BATCH_SIZE)

# Measures initial accuracy of the reference model
model_ref = get_resnet18(num_classes=CLASSES).to(DEVICE)
model_ref.load_state_dict(torch.load(CHECKPOINT_PATH))
acc_A_initial = evaluate(model_ref, test_A, DEVICE, task_classes=TASK_A_INDICES)

for sp in sparsity_targets:
    print(f"\n   >>> Sparsity Target: {sp*100:.0f}%")

    for epochs_b in TASK_B_EPOCHS_LIST:
        print(f"      > Epochs: {epochs_b}")

        # Resets model state to the pre-trained expert
        model_current = get_resnet18(num_classes=CLASSES).to(DEVICE)
        model_current.load_state_dict(torch.load(CHECKPOINT_PATH))

        # Initializes the Magnitude Pruning projector
        projector = MagnitudePruningProjector(sparsity_target=sp)

        if torch.cuda.is_available():
            torch.cuda.reset_peak_memory_stats()
            torch.cuda.empty_cache()

        start_time = time.time()
        projector.compute_subspaces(model_current)
        prep_time = time.time() - start_time

        if torch.cuda.is_available():
            peak_vram = torch.cuda.max_memory_allocated() / (1024 ** 2)
        else:
            peak_vram = 0

        # Evaluates zero-shot accuracy to quantify compression damage
        acc_A_zero = evaluate(model_current, test_A, DEVICE, task_classes=TASK_A_INDICES)
        compression_damage = acc_A_initial - acc_A_zero
        print(f"Zero-Shot: {acc_A_zero:.2f}% (Damage: {compression_damage:.2f}%)")

        # Records initial weights for drift calculation
        w_start = {name: param.detach().cpu().clone() for name, param in model_current.named_parameters()}

        # Performs constrained training on Task B
        model_current, history = train_constrained(model_current, train_B, epochs_b, DEVICE, projector)

        # Computes final performance metrics
        acc_A_final = evaluate(model_current, test_A, DEVICE, task_classes=TASK_A_INDICES)
        acc_B_final = evaluate(model_current, test_B, DEVICE, task_classes=TASK_B_INDICES)

        global_acc = (acc_A_final + acc_B_final) / 2
        forgetting = acc_A_zero - acc_A_final
        train_acc = history['accuracy'][-1]

        drift_sq = 0.0
        for name, param in model_current.named_parameters():
                if name in w_start:
                    diff = param.detach().cpu() - w_start[name]
                    drift_sq += torch.sum(diff ** 2).item()
        weight_drift = drift_sq ** 0.5

        results.append({
            "Method": "Pruning",
            "Hyperparam": sp,
            "Epochs": epochs_b,
            "Global Acc": global_acc,
            "Task A Acc (Retention)": acc_A_final,
            "Task B Acc (Plasticity)": acc_B_final,
            "Train Acc": train_acc,
            "Zero-Shot A": acc_A_zero,
            "Compression Damage": compression_damage,
            "Forgetting": forgetting,
            "Peak VRAM (MB)": peak_vram,
            "Weight Drift": weight_drift,
            "Prep Time (s)": prep_time
        })
        print(f"Result: Global={global_acc:.2f}%, A={acc_A_final:.2f}%, B={acc_B_final:.2f}%, Train={train_acc:.2f}%")
# Out:
# --- Experiment: Global Magnitude Pruning ---
#
#    >>> Sparsity Target: 20%
#       > Epochs: 2
# Pruning 21 layers with Global Sparsity 20.0%...
# Global Sparsity Achieved: 20.00%
# Zero-Shot: 87.22% (Damage: 0.08%)
# Starting Constrained Training (Method: MagnitudePruningProjector)...
# Epoch 1/2 | Loss: 0.6299 | Acc: 81.43%
# Epoch 2/2 | Loss: 0.2871 | Acc: 89.87%
# Result: Global=64.67%, A=38.78%, B=90.56%, Train=89.87%
#       > Epochs: 4
# Pruning 21 layers with Global Sparsity 20.0%...
# Global Sparsity Achieved: 20.00%
# Zero-Shot: 87.22% (Damage: 0.08%)
# Starting Constrained Training (Method: MagnitudePruningProjector)...
# Epoch 1/4 | Loss: 0.6496 | Acc: 80.39%
# Epoch 2/4 | Loss: 0.2973 | Acc: 89.26%
# Epoch 3/4 | Loss: 0.2350 | Acc: 91.81%
# Epoch 4/4 | Loss: 0.2002 | Acc: 92.70%
# Result: Global=64.07%, A=38.20%, B=89.94%, Train=92.70%
#       > Epochs: 6
# Pruning 21 layers with Global Sparsity 20.0%...
# Global Sparsity Achieved: 20.00%
# Zero-Shot: 87.22% (Damage: 0.08%)
# Starting Constrained Training (Method: MagnitudePruningProjector)...
# Epoch 1/6 | Loss: 0.6245 | Acc: 81.35%
# Epoch 2/6 | Loss: 0.2850 | Acc: 89.69%
# Epoch 3/6 | Loss: 0.2304 | Acc: 91.80%
# Epoch 4/6 | Loss: 0.1964 | Acc: 92.96%
# Epoch 5/6 | Loss: 0.1646 | Acc: 94.12%
# Epoch 6/6 | Loss: 0.1434 | Acc: 94.88%
# Result: Global=60.52%, A=28.56%, B=92.48%, Train=94.88%
#       > Epochs: 8
# Pruning 21 layers with Global Sparsity 20.0%...
# Global Sparsity Achieved: 20.00%
# Zero-Shot: 87.22% (Damage: 0.08%)
# Starting Constrained Training (Method: MagnitudePruningProjector)...
# Epoch 1/8 | Loss: 0.6313 | Acc: 81.38%
# Epoch 2/8 | Loss: 0.2876 | Acc: 89.80%
# Epoch 3/8 | Loss: 0.2320 | Acc: 91.76%
# Epoch 4/8 | Loss: 0.1942 | Acc: 93.02%
# Epoch 5/8 | Loss: 0.1675 | Acc: 94.14%
# Epoch 6/8 | Loss: 0.1478 | Acc: 94.80%
# Epoch 7/8 | Loss: 0.1234 | Acc: 95.58%
# Epoch 8/8 | Loss: 0.1054 | Acc: 96.27%
# Result: Global=55.55%, A=20.56%, B=90.54%, Train=96.27%

# %%
# --- Results Aggregation and Export ---
df_results = pd.DataFrame(results)
print("\n=== Final Results Summary ===")
print(df_results)

df_results.to_csv("main_experiment_results.csv", index=False)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Data Loading and Preparation
df = pd.read_csv('main_experiment_results.csv')

# Filters results for the 4-epoch comparison
df_plot = df[df['Epochs'] == 4].copy()

# Reshapes DataFrame for side-by-side bar plotting
# Converts wide format to long format: (Method, Task Type, Accuracy)
df_melted = df_plot.melt(
    id_vars=['Method'],
    value_vars=['Task B Acc (Plasticity)', 'Task A Acc (Retention)'],
    var_name='Metric',
    value_name='Accuracy'
)

# Standardizes metric names for legend clarity
df_melted['Metric'] = df_melted['Metric'].replace({
    'Task B Acc (Plasticity)': 'Task B (New Task)',
    'Task A Acc (Retention)': 'Task A (Old Task)'
})

# Configures visual style preferences
sns.set_theme(style="whitegrid", context="talk")
plt.rcParams['font.family'] = 'sans-serif'

# Generates the comparative bar chart
plt.figure(figsize=(12, 8))

ax = sns.barplot(
    data=df_melted,
    x='Method',
    y='Accuracy',
    hue='Metric',
    palette=['#1f77b4', '#ff7f0e'], # Blue (Left) for Task B, Orange (Right) for Task A
    edgecolor="black",
    alpha=0.9
)

# Applies plot formatting and labels
plt.title("Comparison at 4 Epochs: Learning (Task B) vs. Remembering (Task A)", fontweight='bold')
plt.ylabel("Accuracy (%)")
plt.xlabel("Method")
plt.ylim(0, 110) # Adjusts y-axis to accommodate legend placement
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.00), ncol=2, frameon=False)
plt.xticks(rotation=45)

# Annotates bars with specific accuracy values
for container in ax.containers:
    ax.bar_label(container, fmt='%.1f', padding=3, fontsize=10)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Data Loading and Preparation
df = pd.read_csv('main_experiment_results.csv')

# Filters results for the 4-epoch comparison
df_plot = df[df['Epochs'] == 6].copy()

# Reshapes DataFrame for side-by-side bar plotting
# Converts wide format to long format: (Method, Task Type, Accuracy)
df_melted = df_plot.melt(
    id_vars=['Method'],
    value_vars=['Task B Acc (Plasticity)', 'Task A Acc (Retention)'],
    var_name='Metric',
    value_name='Accuracy'
)

# Standardizes metric names for legend clarity
df_melted['Metric'] = df_melted['Metric'].replace({
    'Task B Acc (Plasticity)': 'Task B (New Task)',
    'Task A Acc (Retention)': 'Task A (Old Task)'
})

# Configures visual style preferences
sns.set_theme(style="whitegrid", context="talk")
plt.rcParams['font.family'] = 'sans-serif'

# Generates the comparative bar chart
plt.figure(figsize=(12, 8))

ax = sns.barplot(
    data=df_melted,
    x='Method',
    y='Accuracy',
    hue='Metric',
    palette=['#1f77b4', '#ff7f0e'], # Blue (Left) for Task B, Orange (Right) for Task A
    edgecolor="black",
    alpha=0.9
)

# Applies plot formatting and labels
plt.title("Comparison at 6 Epochs: Learning (Task B) vs. Remembering (Task A)", fontweight='bold')
plt.ylabel("Accuracy (%)")
plt.xlabel("Method")
plt.ylim(0, 110) # Adjusts y-axis to accommodate legend placement
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.00), ncol=2, frameon=False)
plt.xticks(rotation=45)

# Annotates bars with specific accuracy values
for container in ax.containers:
    ax.bar_label(container, fmt='%.1f', padding=3, fontsize=10)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# --- 1. Load and Prepare Data ---
df = pd.read_csv('main_experiment_results.csv')

# Ensure Epochs is treated as a number for line plots
df['Epochs'] = pd.to_numeric(df['Epochs'])

# Set professional plot style
sns.set_theme(style="whitegrid", context="talk")
plt.rcParams['font.family'] = 'sans-serif'

# ==========================================
# Plot 1: Retention Leaderboard (Bar Chart)
# ==========================================
plt.figure(figsize=(12, 6))
# Sort methods by their average retention across all epochs
order_retention = df.groupby('Method')['Task A Acc (Retention)'].mean().sort_values(ascending=False).index

sns.barplot(
    data=df,
    x="Method",
    y="Task A Acc (Retention)",
    order=order_retention,
    palette="Blues_r", # Darker blue = Better
    edgecolor="black",
    errorbar=None      # Clean look without error bars
)
plt.title("Leaderboard: Average Retention Accuracy (Higher is Better)", fontweight='bold')
plt.ylabel("Task A Accuracy (%)")
plt.xlabel("Method")
plt.ylim(0, 100)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# ==========================================
# Plot 2: The "Sweet Spot" (Time vs. Retention)
# ==========================================
# We use the average performance to simplify the scatter plot
df_avg = df.groupby('Method')[['Prep Time (s)', 'Task A Acc (Retention)']].mean().reset_index()

plt.figure(figsize=(11, 7))
sns.scatterplot(
    data=df_avg,
    x="Prep Time (s)",
    y="Task A Acc (Retention)",
    hue="Method",
    style="Method",
    s=300, # Large markers
    palette="deep",
    alpha=0.9,
    legend=False # Labels are added directly to points
)

# Label points
for i in range(df_avg.shape[0]):
    plt.text(
        df_avg['Prep Time (s)'].iloc[i] + 0.05,
        df_avg['Task A Acc (Retention)'].iloc[i] + 0.5,
        df_avg['Method'].iloc[i],
        fontsize=12,
        weight='bold'
    )

plt.title("The 'Sweet Spot': Speed vs. Accuracy Trade-off", fontweight='bold')
plt.xlabel("Preparation Time (Seconds) - Log Scale recommended if gap is huge")
plt.ylabel("Average Retention Accuracy (%)")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# ==========================================
# Plot 3: Retention Trend (Line Plot)
# ==========================================
plt.figure(figsize=(12, 7))
sns.lineplot(
    data=df,
    x="Epochs",
    y="Task A Acc (Retention)",
    hue="Method",
    style="Method",
    markers=True,
    dashes=False,
    palette="deep",
    linewidth=3,
    markersize=10
)
plt.title("Stability Dynamics: Does training longer hurt memory?", fontweight='bold')
plt.ylabel("Task A Accuracy (%)")
plt.xlabel("Fine-Tuning Epochs")
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# ==========================================
# Plot 4: Plasticity Trend (Line Plot)
# ==========================================
plt.figure(figsize=(12, 7))
sns.lineplot(
    data=df,
    x="Epochs",
    y="Task B Acc (Plasticity)",
    hue="Method",
    style="Method",
    markers=True,
    dashes=False,
    palette="Greens_r",
    linewidth=3,
    markersize=10
)
plt.title("Plasticity Dynamics: New Task Learning Curve", fontweight='bold')
plt.ylabel("Task B Accuracy (%)")
plt.xlabel("Fine-Tuning Epochs")
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# ==========================================
# Plot 5: Mechanism Check (Drift vs. Forgetting)
# ==========================================
plt.figure(figsize=(11, 7))
sns.scatterplot(
    data=df,
    x="Weight Drift",
    y="Forgetting",
    hue="Method",
    style="Epochs", # Shape shows if it's 2, 4, 6, 8 epochs
    s=200,
    palette="viridis",
    alpha=0.9
)

# Add Trend Line
sns.regplot(
    data=df,
    x="Weight Drift",
    y="Forgetting",
    scatter=False,
    color="grey",
    line_kws={"linestyle": "--", "label": "Correlation Trend"}
)

plt.title("Mechanism: Higher Drift leads to More Forgetting", fontweight='bold')
plt.xlabel("Weight Drift (L2 Distance)")
plt.ylabel("Forgetting Score (Lower is Better)")
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# ==========================================
# Plot 6: VRAM Efficiency
# ==========================================
df_vram_avg = df.groupby('Method')[['Peak VRAM (MB)', 'Task A Acc (Retention)']].mean().reset_index()

plt.figure(figsize=(11, 7))
sns.scatterplot(
    data=df_vram_avg,
    x="Peak VRAM (MB)",
    y="Task A Acc (Retention)",
    hue="Method",
    style="Method",
    s=300,
    palette="Reds_r",
    alpha=0.9,
    legend=False
)

for i in range(df_vram_avg.shape[0]):
    plt.text(
        df_vram_avg['Peak VRAM (MB)'].iloc[i] + 10,
        df_vram_avg['Task A Acc (Retention)'].iloc[i] + 0.5,
        df_vram_avg['Method'].iloc[i],
        fontsize=12,
        weight='bold'
    )

plt.title("Memory Efficiency: VRAM Cost vs. Retention", fontweight='bold')
plt.xlabel("Peak VRAM Usage (MB) - Lower is Better")
plt.ylabel("Average Retention Accuracy (%)")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3290726705.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data Loading and Preparation
df = pd.read_csv('main_experiment_results.csv')

# Filter Data
# Added Naive for comparison
df_naive = df[(df['Method'] == 'Naive') & (df['Epochs'] == 6)].copy()
df_adaptive = df[(df['Method'] == 'Adaptive SVD') & (df['Epochs'] == 6)].copy()
df_rsvd = df[(df['Method'] == 'RSVD') & (df['Epochs'] == 6) & (df['Hyperparam'] == 0.4)].copy()

# Concatenate: Naive (Baseline) -> Adaptive -> RSVD
df_table = pd.concat([df_naive, df_adaptive, df_rsvd])

# Select and Rename Columns (Removed Zero-Shot)
cols_map = {
    'Method': 'Method',
    'Task A Acc (Retention)': 'Retention (%)',
    'Task B Acc (Plasticity)': 'Plasticity (%)',
    'Forgetting': 'Forgetting',
    'Peak VRAM (MB)': 'VRAM (MB)',
    'Prep Time (s)': 'Time (s)'
}

df_view = df_table[cols_map.keys()].rename(columns=cols_map)

# Applies plot formatting and labels numbers
df_view['Retention (%)'] = df_view['Retention (%)'].round(2)
df_view['Plasticity (%)'] = df_view['Plasticity (%)'].round(2)
df_view['Forgetting'] = df_view['Forgetting'].round(2)
df_view['VRAM (MB)'] = df_view['VRAM (MB)'].round(0).astype(int)
df_view['Time (s)'] = df_view['Time (s)'].round(3)

# --- Create Visual Table ---
fig, ax = plt.subplots(figsize=(12, 5)) # Slightly taller for extra row
ax.axis('tight')
ax.axis('off')

# Prepare data list
header = df_view.columns.to_list()
data = df_view.values.tolist()
table_content = [header] + data

# Draw Table
table = ax.table(
    cellText=table_content,
    colLabels=None,
    cellLoc='center',
    loc='center'
)

# Styling
table.auto_set_font_size(False)
table.set_fontsize(13)
table.scale(1.2, 2.5) # Make cells taller and wider

# --- Row Specific Styling ---

# Row 0: Header
for col_idx in range(len(header)):
    cell = table[(0, col_idx)]
    cell.set_facecolor('#404040') # Dark gray header
    cell.set_text_props(color='white', weight='bold')

# Row 1: Naive (Baseline) - Standard White
for col_idx in range(len(header)):
    cell = table[(1, col_idx)]
    cell.set_facecolor('#ffffff')

# Row 2: Adaptive SVD - Light Grey
for col_idx in range(len(header)):
    cell = table[(2, col_idx)]
    cell.set_facecolor('#f2f2f2')

# Row 3: RSVD (Winner) - Light Green
for col_idx in range(len(header)):
    cell = table[(3, col_idx)]
    cell.set_facecolor('#d9ead3')

# Updated Title (Removed "Epoch 4")
plt.title("Statistical Comparison: Naive vs. Adaptive SVD vs. RSVD", fontweight='bold', fontsize=16, y=0.9)
plt.show()
